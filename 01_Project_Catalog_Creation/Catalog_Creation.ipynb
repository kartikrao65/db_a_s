# %%
# %sql
CREATE CATALOG IF NOT EXISTS gdelt_dev
MANAGED LOCATION
'abfss://gdelt@stgdeltkartik02.dfs.core.windows.net/databricks-managed/gdelt_dev/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gdelt_dev.raw;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gdelt_dev.bronze;
CREATE SCHEMA IF NOT EXISTS gdelt_dev.silver;
CREATE SCHEMA IF NOT EXISTS gdelt_dev.gold;
CREATE SCHEMA IF NOT EXISTS gdelt_dev.features;
CREATE SCHEMA IF NOT EXISTS gdelt_dev.ml;
CREATE SCHEMA IF NOT EXISTS gdelt_dev.monitoring;
CREATE SCHEMA IF NOT EXISTS gdelt_dev.reference;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS gdelt_dev.raw.gdelt_landing
LOCATION 'abfss://gdelt@stgdeltkartik02.dfs.core.windows.net/landing/extracted';

# %%
landing_path = "/Volumes/gdelt_dev/raw/gdelt_landing/gkg/ingestion_date=2026-08-07/"

files = dbutils.fs.ls(landing_path)
display(files)
