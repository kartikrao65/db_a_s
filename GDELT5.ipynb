# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikrao65/db_a_s/blob/dev-db/GDELT5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install \
    azure-storage-blob \
    pandas \
    pyarrow \
    scikit-learn \
    optuna \
    joblib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.6/435.6 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 13.6 MB/s eta 0:00:00

# %%
from getpass import getpass

sas_url = getpass(
   )

# %%
from azure.storage.blob import BlobClient

blob_client = BlobClient.from_blob_url(
    sas_url
)

local_file = (
    "/content/article_nlp_profile_v001.parquet"
)

with open(local_file, "wb") as f:
    download_stream = blob_client.download_blob()
    f.write(download_stream.readall())

print("✅ Dataset downloaded successfully")
# Out:
# ✅ Dataset downloaded successfully

# %%
from azure.storage.blob import BlobClient

blob_client = BlobClient.from_blob_url(
    sas_url
)

local_file = (
    "/content/article_nlp_profile_v001.parquet"
)

with open(local_file, "wb") as f:
    download_stream = blob_client.download_blob()
    f.write(download_stream.readall())

print("✅ Dataset downloaded successfully")
# Out:
# ✅ Dataset downloaded successfully

# %%
import pandas as pd

df = pd.read_parquet(
    "/content/article_nlp_profile_v001.parquet"
)

print("Rows    :", df.shape[0])
print("Columns :", df.shape[1])

df.head()
# Out:
# Rows    : 3833
# Columns : 11
#          article_id        published_at  \
# 0  20260808133000-0 2026-08-08 13:30:00
# 1  20260808133000-1 2026-08-08 13:30:00
# 2  20260808133000-2 2026-08-08 13:30:00
# 3  20260808133000-3 2026-08-08 13:30:00
# 4  20260808133000-4 2026-08-08 13:30:00
#
#                                          article_url  \
# 0  https://www.somersetcountygazette.co.uk/news/n...
# 1  http://www.shanghainews.net/news/279227456/inp...
# 2  https://aninews.in/news/business/how-to-choose...
# 3  https://www.dailystar.co.uk/showbiz/jack-p-she...
# 4  http://www.reflector.com/jail_bookings/258031-...
#
#                      source_domain  \
# 0  www.somersetcountygazette.co.uk
# 1             www.shanghainews.net
# 2                       aninews.in
# 3              www.dailystar.co.uk
# 4                www.reflector.com
#
#                                                title  \
# 0  Families retrieve bodies after teenage gunman ...
# ...
